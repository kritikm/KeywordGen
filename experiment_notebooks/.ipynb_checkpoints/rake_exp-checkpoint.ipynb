# %%
# Implementation of RAKE - Rapid Automatic Keyword Extraction algorithm
# as described in:
# Rose, S., D. Engel, N. Cramer, and W. Cowley (2010). 
# Automatic keyword extraction from individual documents.
# In M. W. Berry and J. Kogan (Eds.), Text Mining: Applications and Theory.unknown: John Wiley and Sons, Ltd.
#
# NOTE: The original code (from https://github.com/aneesha/RAKE)
# has been extended by a_medelyan (zelandiya)
# with a set of heuristics to decide whether a phrase is an acceptable candidate
# as well as the ability to set frequency and phrase length parameters
# important when dealing with longer documents
#
# NOTE 2: The code published by a_medelyan (https://github.com/zelandiya/RAKE-tutorial)
# has been additionally extended by Marco Pegoraro to implement the adjoined candidate
# feature described in section 1.2.3 of the original paper. Note that this creates the
# need to modify the metric for the candidate score, because the adjoined candidates
# have a very high score (because of the nature of the original score metric)

from __future__ import absolute_import
from __future__ import print_function
import re
import operator
import six
from six.moves import range
from collections import Counter

debug = False
test = True


def is_number(s):
    try:
        float(s) if '.' in s else int(s)
        return True
    except ValueError:
        return False


def load_stop_words(stop_word_file):
    """
    Utility function to load stop words from a file and return as a list of words
    @param stop_word_file Path and file name of a file containing stop words.
    @return list A list of stop words.
    """
    stop_words = []
    for line in open(stop_word_file):
        if line.strip()[0:1] != "#":
            for word in line.split():  # in case more than one per line
                stop_words.append(word)
    return stop_words


def separate_words(text, min_word_return_size):
    """
    Utility function to return a list of all words that are have a length greater than a specified number of characters.
    @param text The text that must be split in to words.
    @param min_word_return_size The minimum no of characters a word must have to be included.
    """
    splitter = re.compile('\b[^\s]+\b')
    words = []
    for single_word in splitter.split(text):
        current_word = single_word.strip().lower()
        # leave numbers in phrase, but don't count as words, since they tend to invalidate scores of their phrases
        if len(current_word) > min_word_return_size and current_word != '' and not is_number(current_word):
            words.append(current_word)
    return words


def split_sentences(text):
    """
    Utility function to return a list of sentences.
    @param text The text that must be split in to sentences.
    """
    sentence_delimiters = re.compile(u'[\\[\\]\n.!?,;:\t\\-\\"\\(\\)\\\'\u2019\u2013]')
    sentences = sentence_delimiters.split(text)
    return sentences


def build_stop_word_regex(stop_word_list):
    stop_word_regex_list = []
    for word in stop_word_list:
        word_regex = '\\b' + word + '\\b'
        stop_word_regex_list.append(word_regex)
    stop_word_pattern = re.compile('|'.join(stop_word_regex_list), re.IGNORECASE)
    return stop_word_pattern


#
# Function that extracts the adjoined candidates from a list of sentences and filters them by frequency
#
def extract_adjoined_candidates(sentence_list, stoplist, min_keywords, max_keywords, min_freq):
    adjoined_candidates = []
    for s in sentence_list:
        # Extracts the candidates from each single sentence and adds them to the list
        adjoined_candidates += adjoined_candidates_from_sentence(s, stoplist, min_keywords, max_keywords)
    # Filters the candidates and returns them
    return filter_adjoined_candidates(adjoined_candidates, min_freq)


# return adjoined_candidates

#
# Function that extracts the adjoined candidates from a single sentence
#
def adjoined_candidates_from_sentence(s, stoplist, min_keywords, max_keywords):
    # Initializes the candidate list to empty
    candidates = []
    # Splits the sentence to get a list of lowercase words
    sl = s.lower().split()
    # For each possible length of the adjoined candidate
    for num_keywords in range(min_keywords, max_keywords + 1):
        # Until the third-last word
        for i in range(0, len(sl) - num_keywords):
            # Position i marks the first word of the candidate. Proceeds only if it's not a stopword
            if sl[i] not in stoplist:
                candidate = sl[i]
                # Initializes j (the pointer to the next word) to 1
                j = 1
                # Initializes the word counter. This counts the non-stopwords words in the candidate
                keyword_counter = 1
                contains_stopword = False
                # Until the word count reaches the maximum number of keywords or the end is reached
                while keyword_counter < num_keywords and i + j < len(sl):
                    # Adds the next word to the candidate
                    candidate = candidate + ' ' + sl[i + j]
                    # If it's not a stopword, increase the word counter. If it is, turn on the flag
                    if sl[i + j] not in stoplist:
                        keyword_counter += 1
                    else:
                        contains_stopword = True
                    # Next position
                    j += 1
                # Adds the candidate to the list only if:
                # 1) it contains at least a stopword (if it doesn't it's already been considered)
                # AND
                # 2) the last word is not a stopword
                # AND
                # 3) the adjoined candidate keyphrase contains exactly the correct number of keywords (to avoid doubles)
                if contains_stopword and candidate.split()[-1] not in stoplist and keyword_counter == num_keywords:
                    candidates.append(candidate)
    return candidates


#
# Function that filters the adjoined candidates to keep only those that appears with a certain frequency
#
def filter_adjoined_candidates(candidates, min_freq):
    # Creates a dictionary where the key is the candidate and the value is the frequency of the candidate
    candidates_freq = Counter(candidates)
    filtered_candidates = []
    # Uses the dictionary to filter the candidates
    for candidate in candidates:
        freq = candidates_freq[candidate]
        if freq >= min_freq:
            filtered_candidates.append(candidate)
    return filtered_candidates


def generate_candidate_keywords(sentence_list, stopword_pattern, stop_word_list, min_char_length=1, max_words_length=5,
                                min_words_length_adj=1, max_words_length_adj=1, min_phrase_freq_adj=2):
    phrase_list = []
    for s in sentence_list:
        tmp = re.sub(stopword_pattern, '|', s.strip())
        phrases = tmp.split("|")
        for phrase in phrases:
            phrase = phrase.strip().lower()
            if phrase != "" and is_acceptable(phrase, min_char_length, max_words_length):
                phrase_list.append(phrase)
    phrase_list += extract_adjoined_candidates(sentence_list, stop_word_list, min_words_length_adj,
                                               max_words_length_adj, min_phrase_freq_adj)
    return phrase_list


def is_acceptable(phrase, min_char_length, max_words_length):
    # a phrase must have a min length in characters
    if len(phrase) < min_char_length:
        return 0

    # a phrase must have a max number of words
    words = phrase.split()
    if len(words) > max_words_length:
        return 0

    digits = 0
    alpha = 0
    for i in range(0, len(phrase)):
        if phrase[i].isdigit():
            digits += 1
        elif phrase[i].isalpha():
            alpha += 1

    # a phrase must have at least one alpha character
    if alpha == 0:
        return 0

    # a phrase must have more alpha than digits characters
    if digits > alpha:
        return 0
    return 1


def calculate_word_scores(phraseList):
    word_frequency = {}
    word_degree = {}
    for phrase in phraseList:
        word_list = separate_words(phrase, 0)
        word_list_length = len(word_list)
        word_list_degree = word_list_length - 1
        # if word_list_degree > 3: word_list_degree = 3 #exp.
        for word in word_list:
            word_frequency.setdefault(word, 0)
            word_frequency[word] += 1
            word_degree.setdefault(word, 0)
            word_degree[word] += word_list_degree  # orig.
            # word_degree[word] += 1/(word_list_length*1.0) #exp.
    for item in word_frequency:
        word_degree[item] = word_degree[item] + word_frequency[item]

    # Calculate Word scores = deg(w)/frew(w)
    word_score = {}
    for item in word_frequency:
        word_score.setdefault(item, 0)
        word_score[item] = word_degree[item] / (word_frequency[item] * 1.0)  # orig.
    # word_score[item] = word_frequency[item]/(word_degree[item] * 1.0) #exp.
    return word_score


def generate_candidate_keyword_scores(phrase_list, word_score, min_keyword_frequency=1):
    keyword_candidates = {}
    for phrase in phrase_list:
        if min_keyword_frequency > 1:
            if phrase_list.count(phrase) < min_keyword_frequency:
                continue
        keyword_candidates.setdefault(phrase, 0)
        word_list = separate_words(phrase, 0)
        candidate_score = 0
        for word in word_list:
            candidate_score += word_score[word]
        keyword_candidates[phrase] = candidate_score
    return keyword_candidates


class Rake(object):
    def __init__(self, stop_words_path, min_char_length=1, max_words_length=5, min_keyword_frequency=1,
                 min_words_length_adj=1, max_words_length_adj=1, min_phrase_freq_adj=2):
        self.__stop_words_path = stop_words_path
        self.__stop_words_list = load_stop_words(stop_words_path)
        self.__min_char_length = min_char_length
        self.__max_words_length = max_words_length
        self.__min_keyword_frequency = min_keyword_frequency
        self.__min_words_length_adj = min_words_length_adj
        self.__max_words_length_adj = max_words_length_adj
        self.__min_phrase_freq_adj = min_phrase_freq_adj

    def run(self, text):
        sentence_list = split_sentences(text)

        stop_words_pattern = build_stop_word_regex(self.__stop_words_list)

        phrase_list = generate_candidate_keywords(sentence_list, stop_words_pattern, self.__stop_words_list,
                                                  self.__min_char_length, self.__max_words_length,
                                                  self.__min_words_length_adj, self.__max_words_length_adj,
                                                  self.__min_phrase_freq_adj)

        word_scores = calculate_word_scores(phrase_list)

        keyword_candidates = generate_candidate_keyword_scores(phrase_list, word_scores, self.__min_keyword_frequency)

        sorted_keywords = sorted(six.iteritems(keyword_candidates), key=operator.itemgetter(1), reverse=True)
        return sorted_keywords

# %%
import os

# %%
projectDir = os.path.join(os.getcwd(), '..')
songsDir = os.path.join(projectDir, 'full_set')
stopwordsPath = os.path.join(projectDir, 'stopwords')
rake_keys = os.path.join(projectDir, 'rake_keys')

# %%
names = os.listdir(songsDir)

for name in names:
    filePath = os.path.join(songsDir, name)
    if os.path.isfile(filePath):
        with open(filePath) as f:
            print("Extracting keywords from file %s" %name)
            text = f.read()
#             sentenceList = split_sentences(text)
            rake = Rake(stopwordsPath)
            keywords = rake.run(text)
            keywordFile = os.path.join(rake_keys, name)
            with open(keywordFile, 'w') as keyFile:
                for key in keywords:
#                     keyFile.write('%s\t%s\n' %(key[0], key[1]))
                    keyFile.write('%s\n' %(key[0]))
# Out:
# Extracting keywords from file 585
# Extracting keywords from file 765
# Extracting keywords from file 289
# Extracting keywords from file 609
# Extracting keywords from file 756
# Extracting keywords from file 242
# Extracting keywords from file 360
# Extracting keywords from file 460
# Extracting keywords from file 625
# Extracting keywords from file 758
# Extracting keywords from file 481
# Extracting keywords from file 337
# Extracting keywords from file 363
# Extracting keywords from file 558
# Extracting keywords from file 275
# Extracting keywords from file 488
# Extracting keywords from file 618
# Extracting keywords from file 154
# Extracting keywords from file 940
# Extracting keywords from file 728
# Extracting keywords from file 806
# Extracting keywords from file 814
# Extracting keywords from file 67
# Extracting keywords from file 376
# Extracting keywords from file 917
# Extracting keywords from file 51
# Extracting keywords from file 801
# Extracting keywords from file 984
# Extracting keywords from file 685
# Extracting keywords from file 115
# Extracting keywords from file 581
# Extracting keywords from file 805
# Extracting keywords from file 108
# Extracting keywords from file 71
# Extracting keywords from file 240
# Extracting keywords from file 639
# Extracting keywords from file 253
# Extracting keywords from file 461
# Extracting keywords from file 499
# Extracting keywords from file 987
# Extracting keywords from file 846
# Extracting keywords from file 16
# Extracting keywords from file 712
# Extracting keywords from file 180
# Extracting keywords from file 122
# Extracting keywords from file 502
# Extracting keywords from file 241
# Extracting keywords from file 599
# Extracting keywords from file 795
# Extracting keywords from file 817
# Extracting keywords from file 952
# Extracting keywords from file 572
# Extracting keywords from file 648
# Extracting keywords from file 189
# Extracting keywords from file 335
# Extracting keywords from file 670
# Extracting keywords from file 300
# Extracting keywords from file 1024
# Extracting keywords from file 93
# Extracting keywords from file 266
# Extracting keywords from file 853
# Extracting keywords from file 411
# Extracting keywords from file 426
# Extracting keywords from file 591
# Extracting keywords from file 510
# Extracting keywords from file 991
# Extracting keywords from file 842
# Extracting keywords from file 268
# Extracting keywords from file 464
# Extracting keywords from file 506
# Extracting keywords from file 911
# Extracting keywords from file 463
# Extracting keywords from file 528
# Extracting keywords from file 282
# Extracting keywords from file 292
# Extracting keywords from file 402
# Extracting keywords from file 98
# Extracting keywords from file 251
# Extracting keywords from file 354
# Extracting keywords from file 3
# Extracting keywords from file 570
# Extracting keywords from file 610
# Extracting keywords from file 172
# Extracting keywords from file 391
# Extracting keywords from file 646
# Extracting keywords from file 293
# Extracting keywords from file 235
# Extracting keywords from file 263
# Extracting keywords from file 469
# Extracting keywords from file 921
# Extracting keywords from file 555
# Extracting keywords from file 1017
# Extracting keywords from file 137
# Extracting keywords from file 847
# Extracting keywords from file 121
# Extracting keywords from file 518
# Extracting keywords from file 428
# Extracting keywords from file 11
# Extracting keywords from file 616
# Extracting keywords from file 559
# Extracting keywords from file 663
# Extracting keywords from file 543
# Extracting keywords from file 904
# Extracting keywords from file 297
# Extracting keywords from file 708
# Extracting keywords from file 109
# Extracting keywords from file 264
# Extracting keywords from file 594
# Extracting keywords from file 416
# Extracting keywords from file 521
# Extracting keywords from file 496
# Extracting keywords from file 255
# Extracting keywords from file 603
# Extracting keywords from file 336
# Extracting keywords from file 142
# Extracting keywords from file 217
# Extracting keywords from file 343
# Extracting keywords from file 709
# Extracting keywords from file 622
# Extracting keywords from file 953
# Extracting keywords from file 845
# Extracting keywords from file 10
# Extracting keywords from file 399
# Extracting keywords from file 174
# Extracting keywords from file 477
# Extracting keywords from file 624
# Extracting keywords from file 573
# Extracting keywords from file 302
# Extracting keywords from file 23
# Extracting keywords from file 1008
# Extracting keywords from file 257
# Extracting keywords from file 920
# Extracting keywords from file 1010
# Extracting keywords from file 69
# Extracting keywords from file 232
# Extracting keywords from file 972
# Extracting keywords from file 317
# Extracting keywords from file 621
# Extracting keywords from file 774
# Extracting keywords from file 346
# Extracting keywords from file 587
# Extracting keywords from file 538
# Extracting keywords from file 767
# Extracting keywords from file 605
# Extracting keywords from file 404
# Extracting keywords from file 87
# Extracting keywords from file 110
# Extracting keywords from file 42
# Extracting keywords from file 448
# Extracting keywords from file 195
# Extracting keywords from file 768
# Extracting keywords from file 304
# Extracting keywords from file 503
# Extracting keywords from file 351
# Extracting keywords from file 922
# Extracting keywords from file 1
# Extracting keywords from file 784
# Extracting keywords from file 213
# Extracting keywords from file 53
# Extracting keywords from file 753
# Extracting keywords from file 256
# Extracting keywords from file 36
# Extracting keywords from file 880
# Extracting keywords from file 117
# Extracting keywords from file 647
# Extracting keywords from file 197
# Extracting keywords from file 849
# Extracting keywords from file 1015
# Extracting keywords from file 533
# Extracting keywords from file 749
# Extracting keywords from file 899
# Extracting keywords from file 576
# Extracting keywords from file 126
# Extracting keywords from file 675
# Extracting keywords from file 653
# Extracting keywords from file 965
# Extracting keywords from file 957
# Extracting keywords from file 825
# Extracting keywords from file 283
# Extracting keywords from file 803
# Extracting keywords from file 422
# Extracting keywords from file 902
# Extracting keywords from file 597
# Extracting keywords from file 888
# Extracting keywords from file 970
# Extracting keywords from file 173
# Extracting keywords from file 703
# Extracting keywords from file 466
# Extracting keywords from file 933
# Extracting keywords from file 400
# Extracting keywords from file 20
# Extracting keywords from file 915
# Extracting keywords from file 96
# Extracting keywords from file 552
# Extracting keywords from file 785
# Extracting keywords from file 968
# Extracting keywords from file 19
# Extracting keywords from file 378
# Extracting keywords from file 786
# Extracting keywords from file 741
# Extracting keywords from file 851
# Extracting keywords from file 353
# Extracting keywords from file 693
# Extracting keywords from file 415
# Extracting keywords from file 932
# Extracting keywords from file 340
# Extracting keywords from file 838
# Extracting keywords from file 744
# Extracting keywords from file 316
# Extracting keywords from file 348
# Extracting keywords from file 764
# Extracting keywords from file 682
# Extracting keywords from file 568
# Extracting keywords from file 894
# Extracting keywords from file 686
# Extracting keywords from file 277
# Extracting keywords from file 332
# Extracting keywords from file 620
# Extracting keywords from file 355
# Extracting keywords from file 465
# Extracting keywords from file 324
# Extracting keywords from file 1011
# Extracting keywords from file 178
# Extracting keywords from file 101
# Extracting keywords from file 948
# Extracting keywords from file 141
# Extracting keywords from file 796
# Extracting keywords from file 34
# Extracting keywords from file 144
# Extracting keywords from file 589
# Extracting keywords from file 146
# Extracting keywords from file 830
# Extracting keywords from file 793
# Extracting keywords from file 22
# Extracting keywords from file 989
# Extracting keywords from file 739
# Extracting keywords from file 975
# Extracting keywords from file 565
# Extracting keywords from file 837
# Extracting keywords from file 1003
# Extracting keywords from file 1018
# Extracting keywords from file 349
# Extracting keywords from file 525
# Extracting keywords from file 156
# Extracting keywords from file 371
# Extracting keywords from file 313
# Extracting keywords from file 530
# Extracting keywords from file 808
# Extracting keywords from file 254
# Extracting keywords from file 824
# Extracting keywords from file 311
# Extracting keywords from file 225
# Extracting keywords from file 799
# Extracting keywords from file 855
# Extracting keywords from file 438
# Extracting keywords from file 804
# Extracting keywords from file 258
# Extracting keywords from file 409
# Extracting keywords from file 89
# Extracting keywords from file 472
# Extracting keywords from file 1007
# Extracting keywords from file 140
# Extracting keywords from file 980
# Extracting keywords from file 129
# Extracting keywords from file 379
# Extracting keywords from file 132
# Extracting keywords from file 869
# Extracting keywords from file 280
# Extracting keywords from file 513
# Extracting keywords from file 982
# Extracting keywords from file 86
# Extracting keywords from file 986
# Extracting keywords from file 875
# Extracting keywords from file 1013
# Extracting keywords from file 881
# Extracting keywords from file 717
# Extracting keywords from file 748
# Extracting keywords from file 818
# Extracting keywords from file 883
# Extracting keywords from file 740
# Extracting keywords from file 47
# Extracting keywords from file 1029
# Extracting keywords from file 713
# Extracting keywords from file 666
# Extracting keywords from file 705
# Extracting keywords from file 706
# Extracting keywords from file 417
# Extracting keywords from file 864
# Extracting keywords from file 912
# Extracting keywords from file 455
# Extracting keywords from file 459
# Extracting keywords from file 491
# Extracting keywords from file 112
# Extracting keywords from file 827
# Extracting keywords from file 662
# Extracting keywords from file 97
# Extracting keywords from file 893
# Extracting keywords from file 26
# Extracting keywords from file 430
# Extracting keywords from file 347
# Extracting keywords from file 18
# Extracting keywords from file 380
# Extracting keywords from file 778
# Extracting keywords from file 250
# Extracting keywords from file 226
# Extracting keywords from file 1009
# Extracting keywords from file 683
# Extracting keywords from file 966
# Extracting keywords from file 943
# Extracting keywords from file 358
# Extracting keywords from file 436
# Extracting keywords from file 632
# Extracting keywords from file 65
# Extracting keywords from file 493
# Extracting keywords from file 819
# Extracting keywords from file 841
# Extracting keywords from file 8
# Extracting keywords from file 27
# Extracting keywords from file 588
# Extracting keywords from file 887
# Extracting keywords from file 690
# Extracting keywords from file 863
# Extracting keywords from file 857
# Extracting keywords from file 889
# Extracting keywords from file 721
# Extracting keywords from file 669
# Extracting keywords from file 82
# Extracting keywords from file 828
# Extracting keywords from file 480
# Extracting keywords from file 1001
# Extracting keywords from file 1006
# Extracting keywords from file 540
# Extracting keywords from file 498
# Extracting keywords from file 478
# Extracting keywords from file 914
# Extracting keywords from file 259
# Extracting keywords from file 24
# Extracting keywords from file 959
# Extracting keywords from file 650
# Extracting keywords from file 871
# Extracting keywords from file 215
# Extracting keywords from file 60
# Extracting keywords from file 388
# Extracting keywords from file 210
# Extracting keywords from file 79
# Extracting keywords from file 138
# Extracting keywords from file 722
# Extracting keywords from file 608
# Extracting keywords from file 580
# Extracting keywords from file 1005
# Extracting keywords from file 276
# Extracting keywords from file 369
# Extracting keywords from file 848
# Extracting keywords from file 123
# Extracting keywords from file 1025
# Extracting keywords from file 688
# Extracting keywords from file 236
# Extracting keywords from file 221
# Extracting keywords from file 439
# Extracting keywords from file 116
# Extracting keywords from file 286
# Extracting keywords from file 307
# Extracting keywords from file 37
# Extracting keywords from file 779
# Extracting keywords from file 907
# Extracting keywords from file 202
# Extracting keywords from file 678
# Extracting keywords from file 136
# Extracting keywords from file 396
# Extracting keywords from file 183
# Extracting keywords from file 421
# Extracting keywords from file 410
# Extracting keywords from file 629
# Extracting keywords from file 155
# Extracting keywords from file 930
# Extracting keywords from file 373
# Extracting keywords from file 886
# Extracting keywords from file 505
# Extracting keywords from file 689
# Extracting keywords from file 992
# Extracting keywords from file 926
# Extracting keywords from file 537
# Extracting keywords from file 593
# Extracting keywords from file 684
# Extracting keywords from file 32
# Extracting keywords from file 961
# Extracting keywords from file 742
# Extracting keywords from file 909
# Extracting keywords from file 746
# Extracting keywords from file 985
# Extracting keywords from file 988
# Extracting keywords from file 916
# Extracting keywords from file 314
# Extracting keywords from file 74
# Extracting keywords from file 1002
# Extracting keywords from file 1026
# Extracting keywords from file 993
# Extracting keywords from file 942
# Extracting keywords from file 691
# Extracting keywords from file 928
# Extracting keywords from file 162
# Extracting keywords from file 322
# Extracting keywords from file 790
# Extracting keywords from file 557
# Extracting keywords from file 188
# Extracting keywords from file 134
# Extracting keywords from file 710
# Extracting keywords from file 782
# Extracting keywords from file 305
# Extracting keywords from file 752
# Extracting keywords from file 38
# Extracting keywords from file 736
# Extracting keywords from file 403
# Extracting keywords from file 211
# Extracting keywords from file 285
# Extracting keywords from file 362
# Extracting keywords from file 697
# Extracting keywords from file 729
# Extracting keywords from file 598
# Extracting keywords from file 1016
# Extracting keywords from file 92
# Extracting keywords from file 384
# Extracting keywords from file 813
# Extracting keywords from file 5
# Extracting keywords from file 561
# Extracting keywords from file 707
# Extracting keywords from file 771
# Extracting keywords from file 490
# Extracting keywords from file 222
# Extracting keywords from file 821
# Extracting keywords from file 850
# Extracting keywords from file 168
# Extracting keywords from file 9
# Extracting keywords from file 328
# Extracting keywords from file 789
# Extracting keywords from file 359
# Extracting keywords from file 111
# Extracting keywords from file 432
# Extracting keywords from file 583
# Extracting keywords from file 90
# Extracting keywords from file 733
# Extracting keywords from file 281
# Extracting keywords from file 57
# Extracting keywords from file 290
# Extracting keywords from file 52
# Extracting keywords from file 147
# Extracting keywords from file 908
# Extracting keywords from file 218
# Extracting keywords from file 550
# Extracting keywords from file 633
# Extracting keywords from file 128
# Extracting keywords from file 81
# Extracting keywords from file 495
# Extracting keywords from file 700
# Extracting keywords from file 84
# Extracting keywords from file 541
# Extracting keywords from file 896
# Extracting keywords from file 903
# Extracting keywords from file 127
# Extracting keywords from file 345
# Extracting keywords from file 918
# Extracting keywords from file 169
# Extracting keywords from file 219
# Extracting keywords from file 829
# Extracting keywords from file 611
# Extracting keywords from file 106
# Extracting keywords from file 356
# Extracting keywords from file 649
# Extracting keywords from file 958
# Extracting keywords from file 113
# Extracting keywords from file 695
# Extracting keywords from file 500
# Extracting keywords from file 441
# Extracting keywords from file 56
# Extracting keywords from file 440
# Extracting keywords from file 50
# Extracting keywords from file 890
# Extracting keywords from file 554
# Extracting keywords from file 809
# Extracting keywords from file 177
# Extracting keywords from file 320
# Extracting keywords from file 2
# Extracting keywords from file 230
# Extracting keywords from file 323
# Extracting keywords from file 88
# Extracting keywords from file 473
# Extracting keywords from file 734
# Extracting keywords from file 339
# Extracting keywords from file 12
# Extracting keywords from file 352
# Extracting keywords from file 350
# Extracting keywords from file 763
# Extracting keywords from file 246
# Extracting keywords from file 574
# Extracting keywords from file 102
# Extracting keywords from file 604
# Extracting keywords from file 13
# Extracting keywords from file 978
# Extracting keywords from file 271
# Extracting keywords from file 1000
# Extracting keywords from file 269
# Extracting keywords from file 318
# Extracting keywords from file 452
# Extracting keywords from file 655
# Extracting keywords from file 822
# Extracting keywords from file 674
# Extracting keywords from file 319
# Extracting keywords from file 823
# Extracting keywords from file 575
# Extracting keywords from file 1004
# Extracting keywords from file 471
# Extracting keywords from file 834
# Extracting keywords from file 54
# Extracting keywords from file 390
# Extracting keywords from file 91
# Extracting keywords from file 443
# Extracting keywords from file 6
# Extracting keywords from file 517
# Extracting keywords from file 820
# Extracting keywords from file 163
# Extracting keywords from file 534
# Extracting keywords from file 960
# Extracting keywords from file 308
# Extracting keywords from file 76
# Extracting keywords from file 623
# Extracting keywords from file 652
# Extracting keywords from file 615
# Extracting keywords from file 100
# Extracting keywords from file 696
# Extracting keywords from file 206
# Extracting keywords from file 698
# Extracting keywords from file 613
# Extracting keywords from file 511
# Extracting keywords from file 182
# Extracting keywords from file 931
# Extracting keywords from file 433
# Extracting keywords from file 723
# Extracting keywords from file 508
# Extracting keywords from file 1021
# Extracting keywords from file 743
# Extracting keywords from file 239
# Extracting keywords from file 130
# Extracting keywords from file 551
# Extracting keywords from file 446
# Extracting keywords from file 104
# Extracting keywords from file 131
# Extracting keywords from file 374
# Extracting keywords from file 224
# Extracting keywords from file 854
# Extracting keywords from file 859
# Extracting keywords from file 444
# Extracting keywords from file 265
# Extracting keywords from file 781
# Extracting keywords from file 923
# Extracting keywords from file 679
# Extracting keywords from file 529
# Extracting keywords from file 699
# Extracting keywords from file 747
# Extracting keywords from file 419
# Extracting keywords from file 956
# Extracting keywords from file 702
# Extracting keywords from file 716
# Extracting keywords from file 243
# Extracting keywords from file 208
# Extracting keywords from file 231
# Extracting keywords from file 458
# Extracting keywords from file 999
# Extracting keywords from file 476
# Extracting keywords from file 501
# Extracting keywords from file 148
# Extracting keywords from file 950
# Extracting keywords from file 606
# Extracting keywords from file 780
# Extracting keywords from file 927
# Extracting keywords from file 941
# Extracting keywords from file 321
# Extracting keywords from file 564
# Extracting keywords from file 249
# Extracting keywords from file 731
# Extracting keywords from file 153
# Extracting keywords from file 21
# Extracting keywords from file 287
# Extracting keywords from file 427
# Extracting keywords from file 673
# Extracting keywords from file 487
# Extracting keywords from file 381
# Extracting keywords from file 190
# Extracting keywords from file 133
# Extracting keywords from file 939
# Extracting keywords from file 701
# Extracting keywords from file 719
# Extracting keywords from file 527
# Extracting keywords from file 212
# Extracting keywords from file 794
# Extracting keywords from file 516
# Extracting keywords from file 644
# Extracting keywords from file 176
# Extracting keywords from file 906
# Extracting keywords from file 62
# Extracting keywords from file 385
# Extracting keywords from file 523
# Extracting keywords from file 659
# Extracting keywords from file 745
# Extracting keywords from file 368
# Extracting keywords from file 184
# Extracting keywords from file 885
# Extracting keywords from file 660
# Extracting keywords from file 1020
# Extracting keywords from file 627
# Extracting keywords from file 187
# Extracting keywords from file 949
# Extracting keywords from file 579
# Extracting keywords from file 105
# Extracting keywords from file 586
# Extracting keywords from file 267
# Extracting keywords from file 252
# Extracting keywords from file 157
# Extracting keywords from file 519
# Extracting keywords from file 631
# Extracting keywords from file 692
# Extracting keywords from file 125
# Extracting keywords from file 549
# Extracting keywords from file 70
# Extracting keywords from file 29
# Extracting keywords from file 919
# Extracting keywords from file 925
# Extracting keywords from file 775
# Extracting keywords from file 772
# Extracting keywords from file 75
# Extracting keywords from file 365
# Extracting keywords from file 861
# Extracting keywords from file 737
# Extracting keywords from file 891
# Extracting keywords from file 470
# Extracting keywords from file 447
# Extracting keywords from file 626
# Extracting keywords from file 867
# Extracting keywords from file 874
# Extracting keywords from file 730
# Extracting keywords from file 179
# Extracting keywords from file 971
# Extracting keywords from file 592
# Extracting keywords from file 882
# Extracting keywords from file 862
# Extracting keywords from file 150
# Extracting keywords from file 248
# Extracting keywords from file 274
# Extracting keywords from file 531
# Extracting keywords from file 667
# Extracting keywords from file 990
# Extracting keywords from file 167
# Extracting keywords from file 78
# Extracting keywords from file 450
# Extracting keywords from file 151
# Extracting keywords from file 998
# Extracting keywords from file 596
# Extracting keywords from file 981
# Extracting keywords from file 630
# Extracting keywords from file 504
# Extracting keywords from file 1023
# Extracting keywords from file 515
# Extracting keywords from file 423
# Extracting keywords from file 77
# Extracting keywords from file 858
# Extracting keywords from file 370
# Extracting keywords from file 152
# Extracting keywords from file 954
# Extracting keywords from file 386
# Extracting keywords from file 372
# Extracting keywords from file 617
# Extracting keywords from file 143
# Extracting keywords from file 852
# Extracting keywords from file 770
# Extracting keywords from file 994
# Extracting keywords from file 661
# Extracting keywords from file 124
# Extracting keywords from file 1014
# Extracting keywords from file 545
# Extracting keywords from file 656
# Extracting keywords from file 429
# Extracting keywords from file 389
# Extracting keywords from file 535
# Extracting keywords from file 382
# Extracting keywords from file 826
# Extracting keywords from file 726
# Extracting keywords from file 715
# Extracting keywords from file 449
# Extracting keywords from file 158
# Extracting keywords from file 405
# Extracting keywords from file 261
# Extracting keywords from file 720
# Extracting keywords from file 462
# Extracting keywords from file 676
# Extracting keywords from file 760
# Extracting keywords from file 619
# Extracting keywords from file 489
# Extracting keywords from file 492
# Extracting keywords from file 997
# Extracting keywords from file 913
# Extracting keywords from file 119
# Extracting keywords from file 636
# Extracting keywords from file 836
# Extracting keywords from file 638
# Extracting keywords from file 910
# Extracting keywords from file 792
# Extracting keywords from file 482
# Extracting keywords from file 284
# Extracting keywords from file 735
# Extracting keywords from file 193
# Extracting keywords from file 497
# Extracting keywords from file 878
# Extracting keywords from file 160
# Extracting keywords from file 526
# Extracting keywords from file 680
# Extracting keywords from file 170
# Extracting keywords from file 641
# Extracting keywords from file 15
# Extracting keywords from file 944
# Extracting keywords from file 714
# Extracting keywords from file 229
# Extracting keywords from file 192
# Extracting keywords from file 278
# Extracting keywords from file 291
# Extracting keywords from file 560
# Extracting keywords from file 566
# Extracting keywords from file 773
# Extracting keywords from file 237
# Extracting keywords from file 873
# Extracting keywords from file 563
# Extracting keywords from file 14
# Extracting keywords from file 711
# Extracting keywords from file 406
# Extracting keywords from file 85
# Extracting keywords from file 643
# Extracting keywords from file 145
# Extracting keywords from file 724
# Extracting keywords from file 811
# Extracting keywords from file 788
# Extracting keywords from file 532
# Extracting keywords from file 59
# Extracting keywords from file 860
# Extracting keywords from file 244
# Extracting keywords from file 548
# Extracting keywords from file 367
# Extracting keywords from file 602
# Extracting keywords from file 562
# Extracting keywords from file 759
# Extracting keywords from file 25
# Extracting keywords from file 569
# Extracting keywords from file 539
# Extracting keywords from file 612
# Extracting keywords from file 200
# Extracting keywords from file 929
# Extracting keywords from file 361
# Extracting keywords from file 191
# Extracting keywords from file 634
# Extracting keywords from file 201
# Extracting keywords from file 509
# Extracting keywords from file 901
# Extracting keywords from file 969
# Extracting keywords from file 39
# Extracting keywords from file 1022
# Extracting keywords from file 166
# Extracting keywords from file 777
# Extracting keywords from file 964
# Extracting keywords from file 401
# Extracting keywords from file 68
# Extracting keywords from file 431
# Extracting keywords from file 333
# Extracting keywords from file 507
# Extracting keywords from file 55
# Extracting keywords from file 445
# Extracting keywords from file 223
# Extracting keywords from file 590
# Extracting keywords from file 738
# Extracting keywords from file 294
# Extracting keywords from file 220
# Extracting keywords from file 607
# Extracting keywords from file 484
# Extracting keywords from file 963
# Extracting keywords from file 310
# Extracting keywords from file 776
# Extracting keywords from file 876
# Extracting keywords from file 341
# Extracting keywords from file 635
# Extracting keywords from file 694
# Extracting keywords from file 312
# Extracting keywords from file 43
# Extracting keywords from file 44
# Extracting keywords from file 247
# Extracting keywords from file 120
# Extracting keywords from file 453
# Extracting keywords from file 645
# Extracting keywords from file 49
# Extracting keywords from file 835
# Extracting keywords from file 831
# Extracting keywords from file 783
# Extracting keywords from file 807
# Extracting keywords from file 17
# Extracting keywords from file 262
# Extracting keywords from file 329
# Extracting keywords from file 868
# Extracting keywords from file 577
# Extracting keywords from file 967
# Extracting keywords from file 924
# Extracting keywords from file 414
# Extracting keywords from file 366
# Extracting keywords from file 843
# Extracting keywords from file 63
# Extracting keywords from file 418
# Extracting keywords from file 387
# Extracting keywords from file 665
# Extracting keywords from file 234
# Extracting keywords from file 198
# Extracting keywords from file 798
# Extracting keywords from file 1012
# Extracting keywords from file 522
# Extracting keywords from file 547
# Extracting keywords from file 279
# Extracting keywords from file 751
# Extracting keywords from file 524
# Extracting keywords from file 159
# Extracting keywords from file 204
# Extracting keywords from file 640
# Extracting keywords from file 479
# Extracting keywords from file 392
# Extracting keywords from file 946
# Extracting keywords from file 412
# Extracting keywords from file 413
# Extracting keywords from file 58
# Extracting keywords from file 595
# Extracting keywords from file 407
# Extracting keywords from file 103
# Extracting keywords from file 494
# Extracting keywords from file 947
# Extracting keywords from file 900
# Extracting keywords from file 468
# Extracting keywords from file 164
# Extracting keywords from file 637
# Extracting keywords from file 331
# Extracting keywords from file 270
# Extracting keywords from file 474
# Extracting keywords from file 181
# Extracting keywords from file 512
# Extracting keywords from file 171
# Extracting keywords from file 668
# Extracting keywords from file 750
# Extracting keywords from file 301
# Extracting keywords from file 938
# Extracting keywords from file 434
# Extracting keywords from file 544
# Extracting keywords from file 757
# Extracting keywords from file 227
# Extracting keywords from file 976
# Extracting keywords from file 816
# Extracting keywords from file 761
# Extracting keywords from file 725
# Extracting keywords from file 974
# Extracting keywords from file 584
# Extracting keywords from file 94
# Extracting keywords from file 546
# Extracting keywords from file 420
# Extracting keywords from file 556
# Extracting keywords from file 671
# Extracting keywords from file 424
# Extracting keywords from file 61
# Extracting keywords from file 797
# Extracting keywords from file 298
# Extracting keywords from file 334
# Extracting keywords from file 485
# Extracting keywords from file 879
# Extracting keywords from file 945
# Extracting keywords from file 718
# Extracting keywords from file 205
# Extracting keywords from file 299
# Extracting keywords from file 582
# Extracting keywords from file 214
# Extracting keywords from file 844
# Extracting keywords from file 175
# Extracting keywords from file 233
# Extracting keywords from file 600
# Extracting keywords from file 40
# Extracting keywords from file 892
# Extracting keywords from file 344
# Extracting keywords from file 303
# Extracting keywords from file 394
# Extracting keywords from file 196
# Extracting keywords from file 107
# Extracting keywords from file 273
# Extracting keywords from file 66
# Extracting keywords from file 33
# Extracting keywords from file 4
# Extracting keywords from file 755
# Extracting keywords from file 762
# Extracting keywords from file 628
# Extracting keywords from file 207
# Extracting keywords from file 186
# Extracting keywords from file 425
# Extracting keywords from file 216
# Extracting keywords from file 467
# Extracting keywords from file 983
# Extracting keywords from file 657
# Extracting keywords from file 839
# Extracting keywords from file 840
# Extracting keywords from file 935
# Extracting keywords from file 995
# Extracting keywords from file 769
# Extracting keywords from file 114
# Extracting keywords from file 185
# Extracting keywords from file 306
# Extracting keywords from file 1028
# Extracting keywords from file 209
# Extracting keywords from file 48
# Extracting keywords from file 46
# Extracting keywords from file 937
# Extracting keywords from file 435
# Extracting keywords from file 327
# Extracting keywords from file 80
# Extracting keywords from file 973
# Extracting keywords from file 754
# Extracting keywords from file 397
# Extracting keywords from file 73
# Extracting keywords from file 732
# Extracting keywords from file 802
# Extracting keywords from file 996
# Extracting keywords from file 338
# Extracting keywords from file 898
# Extracting keywords from file 672
# Extracting keywords from file 681
# Extracting keywords from file 642
# Extracting keywords from file 260
# Extracting keywords from file 203
# Extracting keywords from file 272
# Extracting keywords from file 194
# Extracting keywords from file 654
# Extracting keywords from file 651
# Extracting keywords from file 83
# Extracting keywords from file 31
# Extracting keywords from file 800
# Extracting keywords from file 895
# Extracting keywords from file 437
# Extracting keywords from file 677
# Extracting keywords from file 833
# Extracting keywords from file 99
# Extracting keywords from file 41
# Extracting keywords from file 475
# Extracting keywords from file 571
# Extracting keywords from file 567
# Extracting keywords from file 161
# Extracting keywords from file 228
# Extracting keywords from file 542
# Extracting keywords from file 810
# Extracting keywords from file 395
# Extracting keywords from file 288
# Extracting keywords from file 877
# Extracting keywords from file 812
# Extracting keywords from file 342
# Extracting keywords from file 296
# Extracting keywords from file 832
# Extracting keywords from file 238
# Extracting keywords from file 787
# Extracting keywords from file 601
# Extracting keywords from file 199
# Extracting keywords from file 364
# Extracting keywords from file 536
# Extracting keywords from file 357
# Extracting keywords from file 704
# Extracting keywords from file 149
# Extracting keywords from file 856
# Extracting keywords from file 295
# Extracting keywords from file 442
# Extracting keywords from file 934
# Extracting keywords from file 936
# Extracting keywords from file 955
# Extracting keywords from file 658
# Extracting keywords from file 383
# Extracting keywords from file 135
# Extracting keywords from file 951
# Extracting keywords from file 664
# Extracting keywords from file 95
# Extracting keywords from file 64
# Extracting keywords from file 553
# Extracting keywords from file 398
# Extracting keywords from file 309
# Extracting keywords from file 456
# Extracting keywords from file 486
# Extracting keywords from file 872
# Extracting keywords from file 979
# Extracting keywords from file 578
# Extracting keywords from file 45
# Extracting keywords from file 454
# Extracting keywords from file 870
# Extracting keywords from file 791
# Extracting keywords from file 326
# Extracting keywords from file 451
# Extracting keywords from file 1027
# Extracting keywords from file 7
# Extracting keywords from file 884
# Extracting keywords from file 139
# Extracting keywords from file 30
# Extracting keywords from file 977
# Extracting keywords from file 687
# Extracting keywords from file 375
# Extracting keywords from file 377
# Extracting keywords from file 72
# Extracting keywords from file 614
# Extracting keywords from file 165
# Extracting keywords from file 727
# Extracting keywords from file 1019
# Extracting keywords from file 897
# Extracting keywords from file 28
# Extracting keywords from file 905
# Extracting keywords from file 457
# Extracting keywords from file 393
# Extracting keywords from file 35
# Extracting keywords from file 520
# Extracting keywords from file 815
# Extracting keywords from file 514
# Extracting keywords from file 245
# Extracting keywords from file 483
# Extracting keywords from file 325
# Extracting keywords from file 408
# Extracting keywords from file 866
# Extracting keywords from file 766
# Extracting keywords from file 315
# Extracting keywords from file 962
# Extracting keywords from file 330
# Extracting keywords from file 118
# Extracting keywords from file 865
